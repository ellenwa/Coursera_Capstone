# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# This Notebook will be shared with peers for review of the Coursera Captone Project

# %%
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner

# %% [markdown]
# This Notebook will be used for the Coursera Capstone Project

# %% [markdown]
# This Notebook has been created for the Coursera Captsone Project(Data Science Course)

# %%
print ("Hello Capstone Project Course")
# Out:
# Hello Capstone Project Course
